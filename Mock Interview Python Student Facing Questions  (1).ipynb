# %% [markdown]
# <h3> Mock Interview Python Screening test </h3>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
dataframe = pd.read_csv("adult_census_data.csv")

# %%
dataframe = pd.read_csv("adult_census_data.csv")
dataframe.info()
dataframe.head()

print(dataframe.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# ...

# %% [markdown]
# <b> Q1. After importing the adult_census_data.csv file, please filter this to include only the following criteria: </b>
# <p>
#
# <li> State-Gov</li>
# <li> Bachelors </li>
# <li> Never-Married </li>
# <li> Adm-Clerical </li>
# <li> Not-in-familiy </li>
# <li> White </li>
# <li> Male </li>
# <li> United States </li>
# <li> <=50K </li>
#
# <b> Feel free to any method to complete this tasks. However, we recommend you use either list filtering [], or .loc to complete this task.</b>

# %% [markdown]
# <b> Put your code below </b>

# %%
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 
                'marital-status', 'occupation', 'relationship', 'race', 'sex', 
                'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']

filtered_df = dataframe[
    (dataframe['workclass'] == ' State-gov') &
    (dataframe['education'] == ' Bachelors') &
    (dataframe['marital-status'] == ' Never-married') &
    (dataframe['occupation'] == ' Adm-clerical') &
    (dataframe['relationship'] == ' Not-in-family') &
    (dataframe['race'] == ' White') &
    (dataframe['sex'] == ' Male') &
    (dataframe['native-country'] == ' United-States') &
    (dataframe['income'] == ' <=50K')
]


required_columns = ['workclass', 'education', 'marital-status', 'occupation', 
                    'relationship', 'race', 'sex', 'native-country', 'income']

filtered_df = filtered_df[required_columns]


print(filtered_df)
# Out:
#         workclass   education  marital-status     occupation    relationship  \
# 0       State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
# 1112    State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
# 1873    State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
# 3970    State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
# 10527   State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
# 18774   State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
# 23817   State-gov   Bachelors   Never-married   Adm-clerical   Not-in-family
#
#          race    sex  native-country  income
# 0       White   Male   United-States   <=50K
# 1112    White   Male   United-States   <=50K
# 1873    White   Male   United-States   <=50K
# 3970    White   Male   United-States   <=50K
# 10527   White   Male   United-States   <=50K
# 18774   White   Male   United-States   <=50K
# ...

# %% [markdown]
# <b> Currently, the dataframe you are using has the following column names: </b>
#
# [' State-gov', ' Bachelors', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' United-States', ' <=50K']
#
#
# <b> Q2. Please re-name all the newly filtered columns in the pandas DataFrame to the following: </b>
#
# Employment Type, Degree Status, Marriage-Status, Job-Role, Family-Role, Ethnicity, Gender, Country, Earnings
#
# E.g. State-Gov becomes Employment Type, Bachelors becomes Degree Status, etc.

# %% [markdown]
# <b> Put your code below </b>

# %%
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 
                'marital-status', 'occupation', 'relationship', 'race', 'sex', 
                'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']

filtered_df = dataframe[
    (dataframe['workclass'] == ' State-gov') &
    (dataframe['education'] == ' Bachelors') &
    (dataframe['marital-status'] == ' Never-married') &
    (dataframe['occupation'] == ' Adm-clerical') &
    (dataframe['relationship'] == ' Not-in-family') &
    (dataframe['race'] == ' White') &
    (dataframe['sex'] == ' Male') &
    (dataframe['native-country'] == ' United-States') &
    (dataframe['income'] == ' <=50K')
]


required_columns = ['workclass', 'education', 'marital-status', 'occupation', 
                    'relationship', 'race', 'sex', 'native-country', 'income']

filtered_df = filtered_df[required_columns]

filtered_df = filtered_df.rename(columns={
    'workclass': 'Employment Type',
    'education': 'Degree Status',
    'marital-status': 'Marriage-Status',
    'occupation': 'Job-Role',
    'relationship': 'Family-Role',
    'race': 'Ethnicity',
    'sex': 'Gender',
    'native-country': 'Country',
    'income': 'Earnings'
})

print(filtered_df)
# Out:
#       Employment Type Degree Status Marriage-Status       Job-Role  \
# 0           State-gov     Bachelors   Never-married   Adm-clerical
# 1112        State-gov     Bachelors   Never-married   Adm-clerical
# 1873        State-gov     Bachelors   Never-married   Adm-clerical
# 3970        State-gov     Bachelors   Never-married   Adm-clerical
# 10527       State-gov     Bachelors   Never-married   Adm-clerical
# 18774       State-gov     Bachelors   Never-married   Adm-clerical
# 23817       State-gov     Bachelors   Never-married   Adm-clerical
#
#           Family-Role Ethnicity Gender         Country Earnings
# 0       Not-in-family     White   Male   United-States    <=50K
# 1112    Not-in-family     White   Male   United-States    <=50K
# 1873    Not-in-family     White   Male   United-States    <=50K
# 3970    Not-in-family     White   Male   United-States    <=50K
# 10527   Not-in-family     White   Male   United-States    <=50K
# ...

# %% [markdown]
# <b> Q3. The Job Role Columns holds the job information for each individual in this census snapshot. Using this column, create a Bar Chart that shows the count of 'Unique' Jobs per Job Group in the "Job-Role" Column in ascending order, as per the provided image below </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
job_counts = filtered_df['Job-Role'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
job_counts.plot(kind='bar')
plt.title('Count of Unique Jobs per Job Group')
plt.xlabel('Job Group')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <b> Q4. Please create two bar plots as per below that show:
#
#     1) The number of individuals who have a High School Graduate Diploma AND earn <=50K in the United States
#     2) The number of individuals who have a High School Graduate Diploma AND earn >50K in the United States
#
# Please note you will be looking specifically at the *Job Role* column

# %% [markdown]
# <b> Put Your Code Below </b>

# %%
low_income_job_counts = low_income_df['occupation'].value_counts().sort_values(ascending=False)


high_income_job_counts = high_income_df['occupation'].value_counts().sort_values(ascending=False)

plt.figure(figsize=(25, 10))


plt.subplot(1, 2, 1)
low_income_job_counts.plot(kind='bar', color='skyblue')
plt.title('Individuals who Earn <=50K, have a High School Graduate Diploma and are in the United States')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.subplot(1, 2, 2)
high_income_job_counts.plot(kind='bar', color='salmon')
plt.title('Individuals who Earn >50K, have a High School Graduate Diploma and are in the United States')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# <H2> Challenge Question </H2>
#
# <b> Q5. Which Job Role has the highest <i> proportion </i> of individuals who earn >50K? </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
proportion_high_income = high_income_job_counts / (high_income_job_counts + low_income_job_counts)

highest_proportion_job_role = proportion_high_income.idxmax()
highest_proportion = proportion_high_income.max()
print(f"The Job Role with the highest proportion of individuals earning >50K is '{highest_proportion_job_role}' "
      f"with a proportion of {highest_proportion:.2f}.")
# Out:
# The Job Role with the highest proportion of individuals earning >50K is ' Exec-managerial' with a proportion of 0.33.
